# %% [markdown]
# <a href="https://colab.research.google.com/github/abubakarshahid439/ABUBAKAR.flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/abubakarshahid439/ABUBAKAR.flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# I choose the ranking improvement lane. The goal is to understand how search results can be ranked better based on user interaction data. This is important because better ranking improves user experience and helps users find relevant results faster.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
# The decision is to determine which search results should appear at the top. The system or product team acts on this decision by adjusting rankings. A wrong recommendation can cause users to see irrelevant results, leading to poor user experience and reduced trust in the system.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
# The dataset contains 5 rows of search interaction data.
# There are 3 total clicks recorded.
# This shows that user behavior (clicks) can be observed and used to guide ranking improvements.

# %%
import pandas as pd

# Create a simple sample dataset
data = {
    'query': ['shoes', 'shoes', 'phone', 'phone', 'laptop'],
    'result_rank': [1, 2, 1, 2, 1],
    'clicked': [1, 0, 1, 0, 1]
}

df = pd.DataFrame(data)

print("Total rows:", len(df))
print("Columns:", df.columns.tolist())
print("Total clicks:", df['clicked'].sum())
# Out:
# Total rows: 5
# Columns: ['query', 'result_rank', 'clicked']
# Total clicks: 3

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# This work can provide observed and measured insights about patterns in search ranking and user clicks. It can support decisions and show directional improvements. However, it cannot prove causation or fully predict how search engines like Google rank results.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
